# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
# %matplotlib inline
import seaborn as sns
sns.set_style(style="darkgrid")

# %%
X,y=datasets.make_blobs()

sns.scatterplot(x=X[:,0],y=X[:,1],hue=y,palette=sns.color_palette("hls",3))
# Out:
# <AxesSubplot:>

# %%
# 轮廓系数
from sklearn.metrics import silhouette_score

# %%
number=5
Kmeans=KMeans(n_clusters=number)

Kmeans.fit(X)
y_=Kmeans.predict(X)

sns.scatterplot(x=X[:,0],y=X[:,1],hue=y_,palette=sns.color_palette("hls",number))
silhouette_score(X,y_)
# Out:
# 0.42691995944984223
