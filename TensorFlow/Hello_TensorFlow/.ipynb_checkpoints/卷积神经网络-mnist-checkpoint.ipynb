# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.examples.tutorials.mnist import input_data
from numba import cuda

# %%
# 加载了数据
mnist=input_data.read_data_sets('./',one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-2-5f6ca8bf9e80>:2: read_data_sets (from tensorflow.examples.tutorials.mnist.input_data) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as: tensorflow_datasets.load('mnist')
# WARNING:tensorflow:From d:\python\venv(data_analysis)\lib\site-packages\tensorflow\examples\tutorials\mnist\input_data.py:296: _maybe_download (from tensorflow.examples.tutorials.mnist.input_data) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From d:\python\venv(data_analysis)\lib\site-packages\tensorflow\examples\tutorials\mnist\input_data.py:299: _extract_images (from tensorflow.examples.tutorials.mnist.input_data) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./train-images-idx3-ubyte.gz
# WARNING:tensorflow:From d:\python\venv(data_analysis)\lib\site-packages\tensorflow\examples\tutorials\mnist\input_data.py:304: _extract_labels (from tensorflow.examples.tutorials.mnist.input_data) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From d:\python\venv(data_analysis)\lib\site-packages\tensorflow\examples\tutorials\mnist\input_data.py:112: _dense_to_one_hot (from tensorflow.examples.tutorials.mnist.input_data) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From d:\python\venv(data_analysis)\lib\site-packages\tensorflow\examples\tutorials\mnist\input_data.py:328: _DataSet.__init__ (from tensorflow.examples.tutorials.mnist.input_data) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/_DataSet.py from tensorflow/models.

# %%
# 创建变量和占位符
X=tf.compat.v1.placeholder(dtype=tf.float64,shape=[None,784])
y=tf.compat.v1.placeholder(dtype=tf.float64,shape=[None,10])

# %%
# 卷积核在神经网络中是变量
# 变量生成方法
def gen_v(shape):
        return tf.Variable(
            initial_value=tf.random.normal(dtype=tf.float64,shape=shape,stddev=0.1),
            dtype=tf.float64)

# %%
# 定义方法，完成卷积操作

def conv(input_data,filters_):
    return tf.nn.conv2d(input=input_data,filters=filters_,strides=[1,1,1,1],padding="SAME")

# %%
# 定义池化操作
def pool(input_data):
    return tf.nn.max_pool(input=input_data,ksize=[1,2,2,1],strides=[1,2,2,1],padding="SAME")

# %%
X
# Out:
# <tf.Tensor 'Placeholder:0' shape=(None, 784) dtype=float64>

# %%
# 第一层卷积
input_data1=tf.reshape(X,shape=[-1,28,28,1])
# 卷积核
filter1=gen_v(shape=[3,3,1,64])
# 偏差 bias
b1=gen_v(shape=[64])
conv1=conv(input_data1,filter1)+b1
# 池化
pool1=pool(conv1)
# 激活 函数
active1=tf.nn.relu(pool1)
active1
# Out:
# <tf.Tensor 'Relu:0' shape=(None, 14, 14, 64) dtype=float64>

# %%
# 第二层卷积

# 使用的是第一层卷积的数据

filter2=gen_v(shape=[3,3,64,64])

b2=gen_v(shape=[64])

conv2=conv(active1,filter2)+b2

# 池化

pool2=pool(conv2)

active2=tf.nn.sigmoid(pool2)
active2.shape
# Out:
# TensorShape([None, 7, 7, 64])

# %%
# 全连接层
# 1024个连接 1024个方程 1024个神经元

fc_w=gen_v(shape=[7*7*64,1024])
fc_b=gen_v(shape=[1024])

conn=tf.matmul(tf.reshape(active2,shape=[-1,7*7*64]),fc_w)+fc_b

# %%
# dropout 仿止过拟合
kp=tf.compat.v1.placeholder(dtype=tf.float64,shape=None)

dropout_=tf.nn.dropout(conn,rate=kp)
dropout_.shape
# Out:
# TensorShape([None, 1024])

# %%
# 输出层
# 10个类别 0 ~ 9
out_w=gen_v(shape=[1024,10])

out_b=gen_v(shape=[10])

out=tf.matmul(dropout_,out_w)+out_b
out
# Out:
# <tf.Tensor 'add_3:0' shape=(None, 10) dtype=float64>

# %%
prob=tf.nn.softmax(out)
# 预测的概率 prob_ 非真实分布
prob
# Out:
# <tf.Tensor 'Softmax:0' shape=(None, 10) dtype=float64>

# %%
# 正实的概率 
y
# Out:
# <tf.Tensor 'Placeholder_1:0' shape=(None, 10) dtype=float64>

# %%
# 交叉熵
cost=tf.reduce_mean(tf.reduce_sum(y*tf.math.log(1/prob),axis=-1))
cost
# Out:
# <tf.Tensor 'Mean:0' shape=() dtype=float64>

# %%
cost2=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prob))
cost2
# Out:
# <tf.Tensor 'Mean_1:0' shape=() dtype=float64>

# %%
adam=tf.compat.v1.train.AdamOptimizer()

# %%
optimizer=adam.minimize(cost)
optimizer
# Out:
# <tf.Operation 'Adam' type=NoOp>

# %%
saver=tf.compat.v1.train.Saver()

# %%
gpu_options = tf.compat.v1.GPUOptions(allow_growth=True)  
config_=tf.compat.v1.ConfigProto(gpu_options=gpu_options,log_device_placement=True,allow_soft_placement=True)

with tf.compat.v1.Session(config=config_) as sess:
    sess.run(tf.compat.v1.global_variables_initializer())
    for i in range(10):
        c=0
        for j in range(100):
            x_train,y_train=mnist.train.next_batch(batch_size=550)
            optimizer_,cost_=sess.run(fetches=[optimizer,cost],feed_dict={X:x_train,y:y_train,kp:0.5})
            c+=cost_/100 
            print("里层循环次数：%d ，每次的损失: %0.4f"%(j,cost_))
        print("------执行的次数是: %d 损失函数是: %0.4f------"%(i,c))
        saver.save(sess,save_path="./cnn/model",global_step=i)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# 里层循环次数：0 ，每次的损失: 19.8866
# 里层循环次数：1 ，每次的损失: 38.8087
# 里层循环次数：2 ，每次的损失: 59.2093
# 里层循环次数：3 ，每次的损失: 54.3969
# 里层循环次数：4 ，每次的损失: 60.9256
# 里层循环次数：5 ，每次的损失: 60.0045
# 里层循环次数：6 ，每次的损失: 39.9149
# 里层循环次数：7 ，每次的损失: 34.2510
# 里层循环次数：8 ，每次的损失: 26.5621
# 里层循环次数：9 ，每次的损失: 17.4608
# 里层循环次数：10 ，每次的损失: 23.9547
# 里层循环次数：11 ，每次的损失: 28.7522
# 里层循环次数：12 ，每次的损失: 29.5885
# 里层循环次数：13 ，每次的损失: 26.2679
# 里层循环次数：14 ，每次的损失: 20.7499
# 里层循环次数：15 ，每次的损失: 18.1000
# 里层循环次数：16 ，每次的损失: 13.2650
# 里层循环次数：17 ，每次的损失: 13.0291
# 里层循环次数：18 ，每次的损失: 16.6669
# 里层循环次数：19 ，每次的损失: 13.6063
# 里层循环次数：20 ，每次的损失: 10.7055
# 里层循环次数：21 ，每次的损失: 13.5566
# 里层循环次数：22 ，每次的损失: 10.6614
# 里层循环次数：23 ，每次的损失: 10.5524
# 里层循环次数：24 ，每次的损失: 9.4325
# 里层循环次数：25 ，每次的损失: 8.5785
# 里层循环次数：26 ，每次的损失: 8.5147
# 里层循环次数：27 ，每次的损失: 6.1141
# 里层循环次数：28 ，每次的损失: 7.4003
# 里层循环次数：29 ，每次的损失: 6.0812
# 里层循环次数：30 ，每次的损失: 6.3478
# 里层循环次数：31 ，每次的损失: 6.4631
# 里层循环次数：32 ，每次的损失: 6.4964
# 里层循环次数：33 ，每次的损失: 4.1382
# 里层循环次数：34 ，每次的损失: 4.1747
# 里层循环次数：35 ，每次的损失: 3.8647
# 里层循环次数：36 ，每次的损失: 5.5833
# 里层循环次数：37 ，每次的损失: 3.5063
# 里层循环次数：38 ，每次的损失: 3.6114
# 里层循环次数：39 ，每次的损失: 4.7122
# 里层循环次数：40 ，每次的损失: 4.4979
# 里层循环次数：41 ，每次的损失: 5.0115
# 里层循环次数：42 ，每次的损失: 3.6263
# 里层循环次数：43 ，每次的损失: 3.6353
# 里层循环次数：44 ，每次的损失: 3.4065
# 里层循环次数：45 ，每次的损失: 2.5616
# 里层循环次数：46 ，每次的损失: 2.2477
# 里层循环次数：47 ，每次的损失: 3.0335
# 里层循环次数：48 ，每次的损失: 2.5264
# 里层循环次数：49 ，每次的损失: 2.8089
# 里层循环次数：50 ，每次的损失: 2.2743
# 里层循环次数：51 ，每次的损失: 3.4768
# 里层循环次数：52 ，每次的损失: 3.1145
# 里层循环次数：53 ，每次的损失: 2.4376
# 里层循环次数：54 ，每次的损失: 2.4203
# 里层循环次数：55 ，每次的损失: 2.1994
# 里层循环次数：56 ，每次的损失: 2.0620
# 里层循环次数：57 ，每次的损失: 1.7512
# 里层循环次数：58 ，每次的损失: 1.2477
# 里层循环次数：59 ，每次的损失: 1.8763
# 里层循环次数：60 ，每次的损失: 1.8535
# 里层循环次数：61 ，每次的损失: 1.5679
# 里层循环次数：62 ，每次的损失: 1.3483
# 里层循环次数：63 ，每次的损失: 1.9379
# 里层循环次数：64 ，每次的损失: 1.1977
# 里层循环次数：65 ，每次的损失: 1.3719
# 里层循环次数：66 ，每次的损失: 1.4278
# 里层循环次数：67 ，每次的损失: 1.4949
# 里层循环次数：68 ，每次的损失: 1.2367
# 里层循环次数：69 ，每次的损失: 0.9483
# 里层循环次数：70 ，每次的损失: 1.4229
# 里层循环次数：71 ，每次的损失: 1.0077
# 里层循环次数：72 ，每次的损失: 1.2854
# 里层循环次数：73 ，每次的损失: 1.1928
# 里层循环次数：74 ，每次的损失: 1.1695
# 里层循环次数：75 ，每次的损失: 0.8923
# 里层循环次数：76 ，每次的损失: 1.2098
# 里层循环次数：77 ，每次的损失: 0.9736
# 里层循环次数：78 ，每次的损失: 1.0000
# 里层循环次数：79 ，每次的损失: 0.9010
# 里层循环次数：80 ，每次的损失: 0.8929
# 里层循环次数：81 ，每次的损失: 0.9170
# 里层循环次数：82 ，每次的损失: 0.8046
# 里层循环次数：83 ，每次的损失: 0.7753
# 里层循环次数：84 ，每次的损失: 0.7671
# 里层循环次数：85 ，每次的损失: 0.8346
# 里层循环次数：86 ，每次的损失: 0.8488
# 里层循环次数：87 ，每次的损失: 0.8325
# 里层循环次数：88 ，每次的损失: 0.7130
# 里层循环次数：89 ，每次的损失: 0.8061
# 里层循环次数：90 ，每次的损失: 0.7363
# 里层循环次数：91 ，每次的损失: 0.7400
# 里层循环次数：92 ，每次的损失: 0.6637
# 里层循环次数：93 ，每次的损失: 0.7215
# 里层循环次数：94 ，每次的损失: 0.7276
# 里层循环次数：95 ，每次的损失: 0.7121
# 里层循环次数：96 ，每次的损失: 0.7912
# 里层循环次数：97 ，每次的损失: 0.6909
# 里层循环次数：98 ，每次的损失: 0.8879
# 里层循环次数：99 ，每次的损失: 0.8888
# ------执行的次数是: 0 损失函数是: 8.5330------
# 里层循环次数：0 ，每次的损失: 0.6569
# 里层循环次数：1 ，每次的损失: 0.8584
# 里层循环次数：2 ，每次的损失: 0.6053
# 里层循环次数：3 ，每次的损失: 0.6699
# 里层循环次数：4 ，每次的损失: 0.6367
# 里层循环次数：5 ，每次的损失: 0.5942
# 里层循环次数：6 ，每次的损失: 0.7502
# 里层循环次数：7 ，每次的损失: 0.6282
# 里层循环次数：8 ，每次的损失: 0.6993
# 里层循环次数：9 ，每次的损失: 0.6950
# 里层循环次数：10 ，每次的损失: 0.6590
# 里层循环次数：11 ，每次的损失: 0.7633
# 里层循环次数：12 ，每次的损失: 0.7003
# 里层循环次数：13 ，每次的损失: 0.6793
# 里层循环次数：14 ，每次的损失: 0.7025
# 里层循环次数：15 ，每次的损失: 0.6352
# 里层循环次数：16 ，每次的损失: 0.6897
# 里层循环次数：17 ，每次的损失: 0.5998
# 里层循环次数：18 ，每次的损失: 0.6183
# 里层循环次数：19 ，每次的损失: 0.5559
# 里层循环次数：20 ，每次的损失: 0.6557
# 里层循环次数：21 ，每次的损失: 0.6796
# 里层循环次数：22 ，每次的损失: 0.5246
# 里层循环次数：23 ，每次的损失: 0.6241
# 里层循环次数：24 ，每次的损失: 0.6084
# 里层循环次数：25 ，每次的损失: 0.6783
# 里层循环次数：26 ，每次的损失: 0.6286
# 里层循环次数：27 ，每次的损失: 0.5822
# 里层循环次数：28 ，每次的损失: 0.5657
# 里层循环次数：29 ，每次的损失: 0.5051
# 里层循环次数：30 ，每次的损失: 0.5871
# 里层循环次数：31 ，每次的损失: 0.6102
# 里层循环次数：32 ，每次的损失: 0.5428
# 里层循环次数：33 ，每次的损失: 0.6154
# 里层循环次数：34 ，每次的损失: 0.5709
# 里层循环次数：35 ，每次的损失: 0.5550
# 里层循环次数：36 ，每次的损失: 0.6245
# 里层循环次数：37 ，每次的损失: 0.6339
# 里层循环次数：38 ，每次的损失: 0.5343
# 里层循环次数：39 ，每次的损失: 0.5646
# 里层循环次数：40 ，每次的损失: 0.4935
# 里层循环次数：41 ，每次的损失: 0.6112
# 里层循环次数：42 ，每次的损失: 0.5895
# 里层循环次数：43 ，每次的损失: 0.5723
# 里层循环次数：44 ，每次的损失: 0.5750
# 里层循环次数：45 ，每次的损失: 0.5860
# 里层循环次数：46 ，每次的损失: 0.5627
# 里层循环次数：47 ，每次的损失: 0.6177
# 里层循环次数：48 ，每次的损失: 0.6552
# 里层循环次数：49 ，每次的损失: 0.5553
# 里层循环次数：50 ，每次的损失: 0.5431
# 里层循环次数：51 ，每次的损失: 0.4829
# 里层循环次数：52 ，每次的损失: 0.5464
# 里层循环次数：53 ，每次的损失: 0.4786
# 里层循环次数：54 ，每次的损失: 0.5257
# 里层循环次数：55 ，每次的损失: 0.5758
# 里层循环次数：56 ，每次的损失: 0.4445
# 里层循环次数：57 ，每次的损失: 0.4488
# 里层循环次数：58 ，每次的损失: 0.5405
# 里层循环次数：59 ，每次的损失: 0.4365
# 里层循环次数：60 ，每次的损失: 0.4561
# 里层循环次数：61 ，每次的损失: 0.4747
# 里层循环次数：62 ，每次的损失: 0.4893
# 里层循环次数：63 ，每次的损失: 0.4902
# 里层循环次数：64 ，每次的损失: 0.4605
# 里层循环次数：65 ，每次的损失: 0.4142
# 里层循环次数：66 ，每次的损失: 0.5334
# 里层循环次数：67 ，每次的损失: 0.4948
# 里层循环次数：68 ，每次的损失: 0.5055
# 里层循环次数：69 ，每次的损失: 0.5025
# 里层循环次数：70 ，每次的损失: 0.5310
# 里层循环次数：71 ，每次的损失: 0.4786
# 里层循环次数：72 ，每次的损失: 0.5902
# 里层循环次数：73 ，每次的损失: 0.4171
# 里层循环次数：74 ，每次的损失: 0.4831
# 里层循环次数：75 ，每次的损失: 0.4567
# 里层循环次数：76 ，每次的损失: 0.4554
# 里层循环次数：77 ，每次的损失: 0.4456
# 里层循环次数：78 ，每次的损失: 0.5813
# 里层循环次数：79 ，每次的损失: 0.3867
# 里层循环次数：80 ，每次的损失: 0.4391
# 里层循环次数：81 ，每次的损失: 0.5270
# 里层循环次数：82 ，每次的损失: 0.4025
# 里层循环次数：83 ，每次的损失: 0.4510
# 里层循环次数：84 ，每次的损失: 0.4506
# 里层循环次数：85 ，每次的损失: 0.4205
# 里层循环次数：86 ，每次的损失: 0.4639
# 里层循环次数：87 ，每次的损失: 0.4029
# 里层循环次数：88 ，每次的损失: 0.4560
# 里层循环次数：89 ，每次的损失: 0.4165
# 里层循环次数：90 ，每次的损失: 0.4545
# 里层循环次数：91 ，每次的损失: 0.4135
# 里层循环次数：92 ，每次的损失: 0.4380
# 里层循环次数：93 ，每次的损失: 0.3709
# 里层循环次数：94 ，每次的损失: 0.3900
# 里层循环次数：95 ，每次的损失: 0.4244
# 里层循环次数：96 ，每次的损失: 0.5377
# 里层循环次数：97 ，每次的损失: 0.5657
# 里层循环次数：98 ，每次的损失: 0.4047
# 里层循环次数：99 ，每次的损失: 0.3771
# ------执行的次数是: 1 损失函数是: 0.5458------
# 里层循环次数：0 ，每次的损失: 0.4144
# 里层循环次数：1 ，每次的损失: 0.4067
# 里层循环次数：2 ，每次的损失: 0.4349
# 里层循环次数：3 ，每次的损失: 0.3530
# 里层循环次数：4 ，每次的损失: 0.4747
# 里层循环次数：5 ，每次的损失: 0.3724
# 里层循环次数：6 ，每次的损失: 0.4131
# 里层循环次数：7 ，每次的损失: 0.4319
# 里层循环次数：8 ，每次的损失: 0.4181
# 里层循环次数：9 ，每次的损失: 0.4298
# 里层循环次数：10 ，每次的损失: 0.3625
# 里层循环次数：11 ，每次的损失: 0.3716
# 里层循环次数：12 ，每次的损失: 0.3306
# 里层循环次数：13 ，每次的损失: 0.4208
# 里层循环次数：14 ，每次的损失: 0.3615
# 里层循环次数：15 ，每次的损失: 0.3591
# 里层循环次数：16 ，每次的损失: 0.3980
# 里层循环次数：17 ，每次的损失: 0.3772
# 里层循环次数：18 ，每次的损失: 0.3572
# 里层循环次数：19 ，每次的损失: 0.4461
# 里层循环次数：20 ，每次的损失: 0.3729
# 里层循环次数：21 ，每次的损失: 0.4049
# 里层循环次数：22 ，每次的损失: 0.3843
# 里层循环次数：23 ，每次的损失: 0.3788
# 里层循环次数：24 ，每次的损失: 0.4816
# 里层循环次数：25 ，每次的损失: 0.3750
# 里层循环次数：26 ，每次的损失: 0.3472
# 里层循环次数：27 ，每次的损失: 0.3472
# 里层循环次数：28 ，每次的损失: 0.3711
# 里层循环次数：29 ，每次的损失: 0.3846
# 里层循环次数：30 ，每次的损失: 0.3523
# 里层循环次数：31 ，每次的损失: 0.3948
# 里层循环次数：32 ，每次的损失: 0.3997
# 里层循环次数：33 ，每次的损失: 0.2992
# 里层循环次数：34 ，每次的损失: 0.3401
# 里层循环次数：35 ，每次的损失: 0.3765
# 里层循环次数：36 ，每次的损失: 0.3777
# 里层循环次数：37 ，每次的损失: 0.3432
# 里层循环次数：38 ，每次的损失: 0.4015
# 里层循环次数：39 ，每次的损失: 0.3930
# 里层循环次数：40 ，每次的损失: 0.3405
# 里层循环次数：41 ，每次的损失: 0.3695
# 里层循环次数：42 ，每次的损失: 0.3945
# 里层循环次数：43 ，每次的损失: 0.3696
# 里层循环次数：44 ，每次的损失: 0.4216
# 里层循环次数：45 ，每次的损失: 0.3859
# 里层循环次数：46 ，每次的损失: 0.3771
# 里层循环次数：47 ，每次的损失: 0.4130
# 里层循环次数：48 ，每次的损失: 0.3967
# 里层循环次数：49 ，每次的损失: 0.3213
# 里层循环次数：50 ，每次的损失: 0.3326
# 里层循环次数：51 ，每次的损失: 0.3737
# 里层循环次数：52 ，每次的损失: 0.3056
# 里层循环次数：53 ，每次的损失: 0.3284
# 里层循环次数：54 ，每次的损失: 0.4353
# 里层循环次数：55 ，每次的损失: 0.3360
# 里层循环次数：56 ，每次的损失: 0.3272
# 里层循环次数：57 ，每次的损失: 0.2910
# 里层循环次数：58 ，每次的损失: 0.3395
# 里层循环次数：59 ，每次的损失: 0.4063
# 里层循环次数：60 ，每次的损失: 0.3349
# 里层循环次数：61 ，每次的损失: 0.4038
# 里层循环次数：62 ，每次的损失: 0.3938
# 里层循环次数：63 ，每次的损失: 0.3786
# 里层循环次数：64 ，每次的损失: 0.3398
# 里层循环次数：65 ，每次的损失: 0.3963
# 里层循环次数：66 ，每次的损失: 0.3091
# 里层循环次数：67 ，每次的损失: 0.3548
# 里层循环次数：68 ，每次的损失: 0.3344
# 里层循环次数：69 ，每次的损失: 0.2782
# 里层循环次数：70 ，每次的损失: 0.3156
# 里层循环次数：71 ，每次的损失: 0.3261
# 里层循环次数：72 ，每次的损失: 0.3382
# 里层循环次数：73 ，每次的损失: 0.3357
# 里层循环次数：74 ，每次的损失: 0.3063
# 里层循环次数：75 ，每次的损失: 0.3519
# 里层循环次数：76 ，每次的损失: 0.3033
# 里层循环次数：77 ，每次的损失: 0.3640
# 里层循环次数：78 ，每次的损失: 0.2957
# 里层循环次数：79 ，每次的损失: 0.3462
# 里层循环次数：80 ，每次的损失: 0.2765
# 里层循环次数：81 ，每次的损失: 0.3987
# 里层循环次数：82 ，每次的损失: 0.2906
# 里层循环次数：83 ，每次的损失: 0.3087
# 里层循环次数：84 ，每次的损失: 0.3092
# 里层循环次数：85 ，每次的损失: 0.3108
# 里层循环次数：86 ，每次的损失: 0.3790
# 里层循环次数：87 ，每次的损失: 0.2373
# 里层循环次数：88 ，每次的损失: 0.3106
# 里层循环次数：89 ，每次的损失: 0.3047
# 里层循环次数：90 ，每次的损失: 0.3187
# 里层循环次数：91 ，每次的损失: 0.3485
# 里层循环次数：92 ，每次的损失: 0.3429
# 里层循环次数：93 ，每次的损失: 0.2759
# 里层循环次数：94 ，每次的损失: 0.3056
# 里层循环次数：95 ，每次的损失: 0.3716
# 里层循环次数：96 ，每次的损失: 0.3496
# 里层循环次数：97 ，每次的损失: 0.3557
# 里层循环次数：98 ，每次的损失: 0.3286
# 里层循环次数：99 ，每次的损失: 0.4171
# ------执行的次数是: 2 损失函数是: 0.3607------
# 里层循环次数：0 ，每次的损失: 0.2838
# 里层循环次数：1 ，每次的损失: 0.2680
# 里层循环次数：2 ，每次的损失: 0.3207
# 里层循环次数：3 ，每次的损失: 0.4287
# 里层循环次数：4 ，每次的损失: 0.2324
# 里层循环次数：5 ，每次的损失: 0.2401
# 里层循环次数：6 ，每次的损失: 0.2410
# 里层循环次数：7 ，每次的损失: 0.2658
# 里层循环次数：8 ，每次的损失: 0.2875
# 里层循环次数：9 ，每次的损失: 0.3046
# 里层循环次数：10 ，每次的损失: 0.2647
# 里层循环次数：11 ，每次的损失: 0.3065
# 里层循环次数：12 ，每次的损失: 0.3143
# 里层循环次数：13 ，每次的损失: 0.4153
# 里层循环次数：14 ，每次的损失: 0.2386
# 里层循环次数：15 ，每次的损失: 0.4018
# 里层循环次数：16 ，每次的损失: 0.2547
# 里层循环次数：17 ，每次的损失: 0.2614
# 里层循环次数：18 ，每次的损失: 0.2325
# 里层循环次数：19 ，每次的损失: 0.2649
# 里层循环次数：20 ，每次的损失: 0.2096
# 里层循环次数：21 ，每次的损失: 0.2571
# 里层循环次数：22 ，每次的损失: 0.3072
# 里层循环次数：23 ，每次的损失: 0.2401
# 里层循环次数：24 ，每次的损失: 0.3197
# 里层循环次数：25 ，每次的损失: 0.2288
# 里层循环次数：26 ，每次的损失: 0.2338
# 里层循环次数：27 ，每次的损失: 0.2721
# 里层循环次数：28 ，每次的损失: 0.2557
# 里层循环次数：29 ，每次的损失: 0.3063
# 里层循环次数：30 ，每次的损失: 0.3220
# 里层循环次数：31 ，每次的损失: 0.2463
# 里层循环次数：32 ，每次的损失: 0.2640
# 里层循环次数：33 ，每次的损失: 0.2311
# 里层循环次数：34 ，每次的损失: 0.2173
# 里层循环次数：35 ，每次的损失: 0.2281
# 里层循环次数：36 ，每次的损失: 0.2481
# 里层循环次数：37 ，每次的损失: 0.2324
# 里层循环次数：38 ，每次的损失: 0.3373
# 里层循环次数：39 ，每次的损失: 0.2582
# 里层循环次数：40 ，每次的损失: 0.2470
# 里层循环次数：41 ，每次的损失: 0.2816
# 里层循环次数：42 ，每次的损失: 0.2391
# 里层循环次数：43 ，每次的损失: 0.2640
# 里层循环次数：44 ，每次的损失: 0.2207
# 里层循环次数：45 ，每次的损失: 0.2182
# 里层循环次数：46 ，每次的损失: 0.2825
# 里层循环次数：47 ，每次的损失: 0.2638
# 里层循环次数：48 ，每次的损失: 0.2313
# 里层循环次数：49 ，每次的损失: 0.2647
# 里层循环次数：50 ，每次的损失: 0.2147
# 里层循环次数：51 ，每次的损失: 0.2429
# 里层循环次数：52 ，每次的损失: 0.2812
# 里层循环次数：53 ，每次的损失: 0.2288
# 里层循环次数：54 ，每次的损失: 0.2015
# 里层循环次数：55 ，每次的损失: 0.2205
# 里层循环次数：56 ，每次的损失: 0.2957
# 里层循环次数：57 ，每次的损失: 0.2358
# 里层循环次数：58 ，每次的损失: 0.1718
# 里层循环次数：59 ，每次的损失: 0.2404
# 里层循环次数：60 ，每次的损失: 0.2541
# 里层循环次数：61 ，每次的损失: 0.3147
# 里层循环次数：62 ，每次的损失: 0.3704
# 里层循环次数：63 ，每次的损失: 0.2153
# 里层循环次数：64 ，每次的损失: 0.2277
# 里层循环次数：65 ，每次的损失: 0.3476
# 里层循环次数：66 ，每次的损失: 0.2048
# 里层循环次数：67 ，每次的损失: 0.2846
# 里层循环次数：68 ，每次的损失: 0.2879
# 里层循环次数：69 ，每次的损失: 0.2023
# 里层循环次数：70 ，每次的损失: 0.2792
# 里层循环次数：71 ，每次的损失: 0.1726
# 里层循环次数：72 ，每次的损失: 0.2309
# 里层循环次数：73 ，每次的损失: 0.2243
# 里层循环次数：74 ，每次的损失: 0.2107
# 里层循环次数：75 ，每次的损失: 0.2400
# 里层循环次数：76 ，每次的损失: 0.2099
# 里层循环次数：77 ，每次的损失: 0.3453
# 里层循环次数：78 ，每次的损失: 0.2387
# 里层循环次数：79 ，每次的损失: 0.2531
# 里层循环次数：80 ，每次的损失: 0.2243
# 里层循环次数：81 ，每次的损失: 0.2332
# 里层循环次数：82 ，每次的损失: 0.2880
# 里层循环次数：83 ，每次的损失: 0.2382
# 里层循环次数：84 ，每次的损失: 0.2004
# 里层循环次数：85 ，每次的损失: 0.2500
# 里层循环次数：86 ，每次的损失: 0.2052
# 里层循环次数：87 ，每次的损失: 0.2163
# 里层循环次数：88 ，每次的损失: 0.1932
# 里层循环次数：89 ，每次的损失: 0.2505
# 里层循环次数：90 ，每次的损失: 0.2428
# 里层循环次数：91 ，每次的损失: 0.2106
# 里层循环次数：92 ，每次的损失: 0.2703
# 里层循环次数：93 ，每次的损失: 0.2734
# 里层循环次数：94 ，每次的损失: 0.1898
# 里层循环次数：95 ，每次的损失: 0.2048
# 里层循环次数：96 ，每次的损失: 0.2206
# 里层循环次数：97 ，每次的损失: 0.2659
# 里层循环次数：98 ，每次的损失: 0.2356
# 里层循环次数：99 ，每次的损失: 0.2402
# ------执行的次数是: 3 损失函数是: 0.2566------
# 里层循环次数：0 ，每次的损失: 0.2524
# 里层循环次数：1 ，每次的损失: 0.3178
# 里层循环次数：2 ，每次的损失: 0.2018
# 里层循环次数：3 ，每次的损失: 0.1864
# 里层循环次数：4 ，每次的损失: 0.2103
# 里层循环次数：5 ，每次的损失: 0.2136
# 里层循环次数：6 ，每次的损失: 0.2435
# 里层循环次数：7 ，每次的损失: 0.1429
# 里层循环次数：8 ，每次的损失: 0.2152
# 里层循环次数：9 ，每次的损失: 0.2611
# 里层循环次数：10 ，每次的损失: 0.1851
# 里层循环次数：11 ，每次的损失: 0.2200
# 里层循环次数：12 ，每次的损失: 0.2095
# 里层循环次数：13 ，每次的损失: 0.1733
# 里层循环次数：14 ，每次的损失: 0.2522
# 里层循环次数：15 ，每次的损失: 0.1304
# 里层循环次数：16 ，每次的损失: 0.2640
# 里层循环次数：17 ，每次的损失: 0.2473
# 里层循环次数：18 ，每次的损失: 0.1666
# 里层循环次数：19 ，每次的损失: 0.2539
# 里层循环次数：20 ，每次的损失: 0.2302
# 里层循环次数：21 ，每次的损失: 0.2243
# 里层循环次数：22 ，每次的损失: 0.2587
# 里层循环次数：23 ，每次的损失: 0.1991
# 里层循环次数：24 ，每次的损失: 0.2086
# 里层循环次数：25 ，每次的损失: 0.2414
# 里层循环次数：26 ，每次的损失: 0.2086
# 里层循环次数：27 ，每次的损失: 0.2185
# 里层循环次数：28 ，每次的损失: 0.2487
# 里层循环次数：29 ，每次的损失: 0.1915
# 里层循环次数：30 ，每次的损失: 0.2057
# 里层循环次数：31 ，每次的损失: 0.1392
# 里层循环次数：32 ，每次的损失: 0.1970
# 里层循环次数：33 ，每次的损失: 0.1807
# 里层循环次数：34 ，每次的损失: 0.1963
# 里层循环次数：35 ，每次的损失: 0.2130
# 里层循环次数：36 ，每次的损失: 0.2361
# 里层循环次数：37 ，每次的损失: 0.2564
# 里层循环次数：38 ，每次的损失: 0.3086
# 里层循环次数：39 ，每次的损失: 0.3120
# 里层循环次数：40 ，每次的损失: 0.1828
# 里层循环次数：41 ，每次的损失: 0.2057
# 里层循环次数：42 ，每次的损失: 0.1984
# 里层循环次数：43 ，每次的损失: 0.1720
# 里层循环次数：44 ，每次的损失: 0.2203
# 里层循环次数：45 ，每次的损失: 0.1742
# 里层循环次数：46 ，每次的损失: 0.2375
# 里层循环次数：47 ，每次的损失: 0.2697
# 里层循环次数：48 ，每次的损失: 0.1858
# 里层循环次数：49 ，每次的损失: 0.1684
# 里层循环次数：50 ，每次的损失: 0.2037
# 里层循环次数：51 ，每次的损失: 0.2293
# 里层循环次数：52 ，每次的损失: 0.2808
# 里层循环次数：53 ，每次的损失: 0.1551
# 里层循环次数：54 ，每次的损失: 0.1839
# 里层循环次数：55 ，每次的损失: 0.1990
# 里层循环次数：56 ，每次的损失: 0.2057
# 里层循环次数：57 ，每次的损失: 0.1715
# 里层循环次数：58 ，每次的损失: 0.2095
# 里层循环次数：59 ，每次的损失: 0.1800
# 里层循环次数：60 ，每次的损失: 0.2476
# 里层循环次数：61 ，每次的损失: 0.1843
# 里层循环次数：62 ，每次的损失: 0.1590
# 里层循环次数：63 ，每次的损失: 0.1821
# 里层循环次数：64 ，每次的损失: 0.2667
# 里层循环次数：65 ，每次的损失: 0.1477
# 里层循环次数：66 ，每次的损失: 0.1961
# 里层循环次数：67 ，每次的损失: 0.2204
# 里层循环次数：68 ，每次的损失: 0.1909
# 里层循环次数：69 ，每次的损失: 0.1856
# 里层循环次数：70 ，每次的损失: 0.2144
# 里层循环次数：71 ，每次的损失: 0.2067
# 里层循环次数：72 ，每次的损失: 0.1673
# 里层循环次数：73 ，每次的损失: 0.1420
# 里层循环次数：74 ，每次的损失: 0.2462
# 里层循环次数：75 ，每次的损失: 0.2036
# 里层循环次数：76 ，每次的损失: 0.2164
# 里层循环次数：77 ，每次的损失: 0.1815
# 里层循环次数：78 ，每次的损失: 0.1351
# 里层循环次数：79 ，每次的损失: 0.1664
# 里层循环次数：80 ，每次的损失: 0.1573
# 里层循环次数：81 ，每次的损失: 0.2088
# 里层循环次数：82 ，每次的损失: 0.1776
# 里层循环次数：83 ，每次的损失: 0.1717
# 里层循环次数：84 ，每次的损失: 0.2138
# 里层循环次数：85 ，每次的损失: 0.2036
# 里层循环次数：86 ，每次的损失: 0.1676
# 里层循环次数：87 ，每次的损失: 0.1737
# 里层循环次数：88 ，每次的损失: 0.2195
# 里层循环次数：89 ，每次的损失: 0.1530
# 里层循环次数：90 ，每次的损失: 0.2108
# 里层循环次数：91 ，每次的损失: 0.1724
# 里层循环次数：92 ，每次的损失: 0.1320
# 里层循环次数：93 ，每次的损失: 0.1658
# 里层循环次数：94 ，每次的损失: 0.1642
# 里层循环次数：95 ，每次的损失: 0.1921
# 里层循环次数：96 ，每次的损失: 0.1928
# 里层循环次数：97 ，每次的损失: 0.2142
# 里层循环次数：98 ，每次的损失: 0.1753
# 里层循环次数：99 ，每次的损失: 0.2049
# ------执行的次数是: 4 损失函数是: 0.2039------
# 里层循环次数：0 ，每次的损失: 0.2006
# 里层循环次数：1 ，每次的损失: 0.2510
# 里层循环次数：2 ，每次的损失: 0.2070
# 里层循环次数：3 ，每次的损失: 0.1966
# 里层循环次数：4 ，每次的损失: 0.1681
# 里层循环次数：5 ，每次的损失: 0.1781
# 里层循环次数：6 ，每次的损失: 0.1307
# 里层循环次数：7 ，每次的损失: 0.0999
# 里层循环次数：8 ，每次的损失: 0.1197
# 里层循环次数：9 ，每次的损失: 0.1771
# 里层循环次数：10 ，每次的损失: 0.1679
# 里层循环次数：11 ，每次的损失: 0.1753
# 里层循环次数：12 ，每次的损失: 0.1698
# 里层循环次数：13 ，每次的损失: 0.1716
# 里层循环次数：14 ，每次的损失: 0.1449
# 里层循环次数：15 ，每次的损失: 0.1672
# 里层循环次数：16 ，每次的损失: 0.1773
# 里层循环次数：17 ，每次的损失: 0.1466
# 里层循环次数：18 ，每次的损失: 0.1970
# 里层循环次数：19 ，每次的损失: 0.1799
# 里层循环次数：20 ，每次的损失: 0.1653
# 里层循环次数：21 ，每次的损失: 0.1798
# 里层循环次数：22 ，每次的损失: 0.1584
# 里层循环次数：23 ，每次的损失: 0.1642
# 里层循环次数：24 ，每次的损失: 0.1897
# 里层循环次数：25 ，每次的损失: 0.2008
# 里层循环次数：26 ，每次的损失: 0.1770
# 里层循环次数：27 ，每次的损失: 0.1745
# 里层循环次数：28 ，每次的损失: 0.1850
# 里层循环次数：29 ，每次的损失: 0.1303
# 里层循环次数：30 ，每次的损失: 0.1832
# 里层循环次数：31 ，每次的损失: 0.1933
# 里层循环次数：32 ，每次的损失: 0.1675
# 里层循环次数：33 ，每次的损失: 0.1270
# 里层循环次数：34 ，每次的损失: 0.2301
# 里层循环次数：35 ，每次的损失: 0.1319
# 里层循环次数：36 ，每次的损失: 0.1679
# 里层循环次数：37 ，每次的损失: 0.1886
# 里层循环次数：38 ，每次的损失: 0.1583
# 里层循环次数：39 ，每次的损失: 0.1171
# 里层循环次数：40 ，每次的损失: 0.1676
# 里层循环次数：41 ，每次的损失: 0.1523
# 里层循环次数：42 ，每次的损失: 0.1393
# 里层循环次数：43 ，每次的损失: 0.1848
# 里层循环次数：44 ，每次的损失: 0.1507
# 里层循环次数：45 ，每次的损失: 0.1671
# 里层循环次数：46 ，每次的损失: 0.1671
# 里层循环次数：47 ，每次的损失: 0.1256
# 里层循环次数：48 ，每次的损失: 0.2259
# 里层循环次数：49 ，每次的损失: 0.1679
# 里层循环次数：50 ，每次的损失: 0.2182
# 里层循环次数：51 ，每次的损失: 0.1824
# 里层循环次数：52 ，每次的损失: 0.2097
# 里层循环次数：53 ，每次的损失: 0.2116
# 里层循环次数：54 ，每次的损失: 0.1955
# 里层循环次数：55 ，每次的损失: 0.1564
# 里层循环次数：56 ，每次的损失: 0.1717
# 里层循环次数：57 ，每次的损失: 0.1468
# 里层循环次数：58 ，每次的损失: 0.1643
# 里层循环次数：59 ，每次的损失: 0.1247
# 里层循环次数：60 ，每次的损失: 0.1418
# 里层循环次数：61 ，每次的损失: 0.1623
# 里层循环次数：62 ，每次的损失: 0.1781
# 里层循环次数：63 ，每次的损失: 0.2107
# 里层循环次数：64 ，每次的损失: 0.1645
# 里层循环次数：65 ，每次的损失: 0.1402
# 里层循环次数：66 ，每次的损失: 0.0813
# 里层循环次数：67 ，每次的损失: 0.2164
# 里层循环次数：68 ，每次的损失: 0.1381
# 里层循环次数：69 ，每次的损失: 0.1717
# 里层循环次数：70 ，每次的损失: 0.1415
# 里层循环次数：71 ，每次的损失: 0.1882
# 里层循环次数：72 ，每次的损失: 0.1626
# 里层循环次数：73 ，每次的损失: 0.2560
# 里层循环次数：74 ，每次的损失: 0.1337
# 里层循环次数：75 ，每次的损失: 0.1692
# 里层循环次数：76 ，每次的损失: 0.1750
# 里层循环次数：77 ，每次的损失: 0.2068
# 里层循环次数：78 ，每次的损失: 0.1469
# 里层循环次数：79 ，每次的损失: 0.2046
# 里层循环次数：80 ，每次的损失: 0.1713
# 里层循环次数：81 ，每次的损失: 0.2322
# 里层循环次数：82 ，每次的损失: 0.1470
# 里层循环次数：83 ，每次的损失: 0.2372
# 里层循环次数：84 ，每次的损失: 0.1717
# 里层循环次数：85 ，每次的损失: 0.2291
# 里层循环次数：86 ，每次的损失: 0.1414
# 里层循环次数：87 ，每次的损失: 0.1085
# 里层循环次数：88 ，每次的损失: 0.1834
# 里层循环次数：89 ，每次的损失: 0.1619
# 里层循环次数：90 ，每次的损失: 0.1820
# 里层循环次数：91 ，每次的损失: 0.2535
# 里层循环次数：92 ，每次的损失: 0.1883
# 里层循环次数：93 ，每次的损失: 0.1600
# 里层循环次数：94 ，每次的损失: 0.1518
# 里层循环次数：95 ，每次的损失: 0.1438
# 里层循环次数：96 ，每次的损失: 0.2142
# 里层循环次数：97 ，每次的损失: 0.2147
# 里层循环次数：98 ，每次的损失: 0.1937
# 里层循环次数：99 ，每次的损失: 0.2488
# ------执行的次数是: 5 损失函数是: 0.1737------
# WARNING:tensorflow:From d:\python\venv(data_analysis)\lib\site-packages\tensorflow\python\training\saver.py:968: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# 里层循环次数：0 ，每次的损失: 0.1508
# 里层循环次数：1 ，每次的损失: 0.1425
# 里层循环次数：2 ，每次的损失: 0.2559
# 里层循环次数：3 ，每次的损失: 0.1420
# 里层循环次数：4 ，每次的损失: 0.1639
# 里层循环次数：5 ，每次的损失: 0.2004
# 里层循环次数：6 ，每次的损失: 0.2310
# 里层循环次数：7 ，每次的损失: 0.1640
# 里层循环次数：8 ，每次的损失: 0.1669
# 里层循环次数：9 ，每次的损失: 0.2252
# 里层循环次数：10 ，每次的损失: 0.1757
# 里层循环次数：11 ，每次的损失: 0.1678
# 里层循环次数：12 ，每次的损失: 0.1440
# 里层循环次数：13 ，每次的损失: 0.1630
# 里层循环次数：14 ，每次的损失: 0.1485
# 里层循环次数：15 ，每次的损失: 0.1681
# 里层循环次数：16 ，每次的损失: 0.1455
# 里层循环次数：17 ，每次的损失: 0.1964
# 里层循环次数：18 ，每次的损失: 0.1858
# 里层循环次数：19 ，每次的损失: 0.1356
# 里层循环次数：20 ，每次的损失: 0.1715
# 里层循环次数：21 ，每次的损失: 0.2098
# 里层循环次数：22 ，每次的损失: 0.1617
# 里层循环次数：23 ，每次的损失: 0.1438
# 里层循环次数：24 ，每次的损失: 0.1116
# 里层循环次数：25 ，每次的损失: 0.1734
# 里层循环次数：26 ，每次的损失: 0.1251
# 里层循环次数：27 ，每次的损失: 0.1197
# 里层循环次数：28 ，每次的损失: 0.1905
# 里层循环次数：29 ，每次的损失: 0.1950
# 里层循环次数：30 ，每次的损失: 0.1872
# 里层循环次数：31 ，每次的损失: 0.1128
# 里层循环次数：32 ，每次的损失: 0.1676
# 里层循环次数：33 ，每次的损失: 0.1606
# 里层循环次数：34 ，每次的损失: 0.1828
# 里层循环次数：35 ，每次的损失: 0.1876
# 里层循环次数：36 ，每次的损失: 0.1586
# 里层循环次数：37 ，每次的损失: 0.1514
# 里层循环次数：38 ，每次的损失: 0.1045
# 里层循环次数：39 ，每次的损失: 0.1482
# 里层循环次数：40 ，每次的损失: 0.1391
# 里层循环次数：41 ，每次的损失: 0.1559
# 里层循环次数：42 ，每次的损失: 0.1446
# 里层循环次数：43 ，每次的损失: 0.1480
# 里层循环次数：44 ，每次的损失: 0.1510
# 里层循环次数：45 ，每次的损失: 0.1676
# 里层循环次数：46 ，每次的损失: 0.1573
# 里层循环次数：47 ，每次的损失: 0.1434
# 里层循环次数：48 ，每次的损失: 0.1096
# 里层循环次数：49 ，每次的损失: 0.1605
# 里层循环次数：50 ，每次的损失: 0.1206
# 里层循环次数：51 ，每次的损失: 0.1362
# 里层循环次数：52 ，每次的损失: 0.1495
# 里层循环次数：53 ，每次的损失: 0.1460
# 里层循环次数：54 ，每次的损失: 0.1486
# 里层循环次数：55 ，每次的损失: 0.1692
# 里层循环次数：56 ，每次的损失: 0.1243
# 里层循环次数：57 ，每次的损失: 0.1667
# 里层循环次数：58 ，每次的损失: 0.1671
# 里层循环次数：59 ，每次的损失: 0.1147
# 里层循环次数：60 ，每次的损失: 0.0967
# 里层循环次数：61 ，每次的损失: 0.1520
# 里层循环次数：62 ，每次的损失: 0.1772
# 里层循环次数：63 ，每次的损失: 0.1783
# 里层循环次数：64 ，每次的损失: 0.1760
# 里层循环次数：65 ，每次的损失: 0.1836
# 里层循环次数：66 ，每次的损失: 0.1711
# 里层循环次数：67 ，每次的损失: 0.1630
# 里层循环次数：68 ，每次的损失: 0.1468
# 里层循环次数：69 ，每次的损失: 0.2417
# 里层循环次数：70 ，每次的损失: 0.1825
# 里层循环次数：71 ，每次的损失: 0.1531
# 里层循环次数：72 ，每次的损失: 0.1146
# 里层循环次数：73 ，每次的损失: 0.1437
# 里层循环次数：74 ，每次的损失: 0.1609
# 里层循环次数：75 ，每次的损失: 0.1648
# 里层循环次数：76 ，每次的损失: 0.2173
# 里层循环次数：77 ，每次的损失: 0.1000
# 里层循环次数：78 ，每次的损失: 0.1095
# 里层循环次数：79 ，每次的损失: 0.1255
# 里层循环次数：80 ，每次的损失: 0.1458
# 里层循环次数：81 ，每次的损失: 0.2055
# 里层循环次数：82 ，每次的损失: 0.1383
# 里层循环次数：83 ，每次的损失: 0.1364
# 里层循环次数：84 ，每次的损失: 0.1517
# 里层循环次数：85 ，每次的损失: 0.1097
# 里层循环次数：86 ，每次的损失: 0.1850
# 里层循环次数：87 ，每次的损失: 0.1146
# 里层循环次数：88 ，每次的损失: 0.1696
# 里层循环次数：89 ，每次的损失: 0.1419
# 里层循环次数：90 ，每次的损失: 0.1206
# 里层循环次数：91 ，每次的损失: 0.1346
# 里层循环次数：92 ，每次的损失: 0.1117
# 里层循环次数：93 ，每次的损失: 0.1544
# 里层循环次数：94 ，每次的损失: 0.2239
# 里层循环次数：95 ，每次的损失: 0.1540
# 里层循环次数：96 ，每次的损失: 0.1440
# 里层循环次数：97 ，每次的损失: 0.1197
# 里层循环次数：98 ，每次的损失: 0.1250
# 里层循环次数：99 ，每次的损失: 0.1162
# ------执行的次数是: 6 损失函数是: 0.1562------
# 里层循环次数：0 ，每次的损失: 0.2018
# 里层循环次数：1 ，每次的损失: 0.1939
# 里层循环次数：2 ，每次的损失: 0.1013
# 里层循环次数：3 ，每次的损失: 0.1110
# 里层循环次数：4 ，每次的损失: 0.1756
# 里层循环次数：5 ，每次的损失: 0.1378
# 里层循环次数：6 ，每次的损失: 0.1104
# 里层循环次数：7 ，每次的损失: 0.2242
# 里层循环次数：8 ，每次的损失: 0.1340
# 里层循环次数：9 ，每次的损失: 0.1315
# 里层循环次数：10 ，每次的损失: 0.1299
# 里层循环次数：11 ，每次的损失: 0.1109
# 里层循环次数：12 ，每次的损失: 0.1219
# 里层循环次数：13 ，每次的损失: 0.1073
# 里层循环次数：14 ，每次的损失: 0.1379
# 里层循环次数：15 ，每次的损失: 0.1764
# 里层循环次数：16 ，每次的损失: 0.1982
# 里层循环次数：17 ，每次的损失: 0.1025
# 里层循环次数：18 ，每次的损失: 0.0932
# 里层循环次数：19 ，每次的损失: 0.0968
# 里层循环次数：20 ，每次的损失: 0.1567
# 里层循环次数：21 ，每次的损失: 0.1690
# 里层循环次数：22 ，每次的损失: 0.1341
# 里层循环次数：23 ，每次的损失: 0.1545
# 里层循环次数：24 ，每次的损失: 0.1036
# 里层循环次数：25 ，每次的损失: 0.1574
# 里层循环次数：26 ，每次的损失: 0.1376
# 里层循环次数：27 ，每次的损失: 0.1520
# 里层循环次数：28 ，每次的损失: 0.0807
# 里层循环次数：29 ，每次的损失: 0.1260
# 里层循环次数：30 ，每次的损失: 0.0921
# 里层循环次数：31 ，每次的损失: 0.1482
# 里层循环次数：32 ，每次的损失: 0.1527
# 里层循环次数：33 ，每次的损失: 0.1373
# 里层循环次数：34 ，每次的损失: 0.1260
# 里层循环次数：35 ，每次的损失: 0.1415
# 里层循环次数：36 ，每次的损失: 0.1428
# 里层循环次数：37 ，每次的损失: 0.1317
# 里层循环次数：38 ，每次的损失: 0.0782
# 里层循环次数：39 ，每次的损失: 0.1631
# 里层循环次数：40 ，每次的损失: 0.1406
# 里层循环次数：41 ，每次的损失: 0.0917
# 里层循环次数：42 ，每次的损失: 0.2043
# 里层循环次数：43 ，每次的损失: 0.1233
# 里层循环次数：44 ，每次的损失: 0.1491
# 里层循环次数：45 ，每次的损失: 0.1410
# 里层循环次数：46 ，每次的损失: 0.1357
# 里层循环次数：47 ，每次的损失: 0.1528
# 里层循环次数：48 ，每次的损失: 0.1582
# 里层循环次数：49 ，每次的损失: 0.1328
# 里层循环次数：50 ，每次的损失: 0.1107
# 里层循环次数：51 ，每次的损失: 0.1406
# 里层循环次数：52 ，每次的损失: 0.0665
# 里层循环次数：53 ，每次的损失: 0.1442
# 里层循环次数：54 ，每次的损失: 0.1300
# 里层循环次数：55 ，每次的损失: 0.1086
# 里层循环次数：56 ，每次的损失: 0.1671
# 里层循环次数：57 ，每次的损失: 0.1089
# 里层循环次数：58 ，每次的损失: 0.1680
# 里层循环次数：59 ，每次的损失: 0.1457
# 里层循环次数：60 ，每次的损失: 0.1233
# 里层循环次数：61 ，每次的损失: 0.0992
# 里层循环次数：62 ，每次的损失: 0.1477
# 里层循环次数：63 ，每次的损失: 0.1511
# 里层循环次数：64 ，每次的损失: 0.1485
# 里层循环次数：65 ，每次的损失: 0.1548
# 里层循环次数：66 ，每次的损失: 0.1361
# 里层循环次数：67 ，每次的损失: 0.1157
# 里层循环次数：68 ，每次的损失: 0.1392
# 里层循环次数：69 ，每次的损失: 0.1683
# 里层循环次数：70 ，每次的损失: 0.1251
# 里层循环次数：71 ，每次的损失: 0.1551
# 里层循环次数：72 ，每次的损失: 0.0901
# 里层循环次数：73 ，每次的损失: 0.1192
# 里层循环次数：74 ，每次的损失: 0.1477
# 里层循环次数：75 ，每次的损失: 0.1080
# 里层循环次数：76 ，每次的损失: 0.1868
# 里层循环次数：77 ，每次的损失: 0.1254
# 里层循环次数：78 ，每次的损失: 0.1723
# 里层循环次数：79 ，每次的损失: 0.2035
# 里层循环次数：80 ，每次的损失: 0.1558
# 里层循环次数：81 ，每次的损失: 0.1410
# 里层循环次数：82 ，每次的损失: 0.1145
# 里层循环次数：83 ，每次的损失: 0.0754
# 里层循环次数：84 ，每次的损失: 0.1320
# 里层循环次数：85 ，每次的损失: 0.1400
# 里层循环次数：86 ，每次的损失: 0.1527
# 里层循环次数：87 ，每次的损失: 0.1099
# 里层循环次数：88 ，每次的损失: 0.1514
# 里层循环次数：89 ，每次的损失: 0.1161
# 里层循环次数：90 ，每次的损失: 0.0988
# 里层循环次数：91 ，每次的损失: 0.1885
# 里层循环次数：92 ，每次的损失: 0.1046
# 里层循环次数：93 ，每次的损失: 0.1435
# 里层循环次数：94 ，每次的损失: 0.0970
# 里层循环次数：95 ，每次的损失: 0.1698
# 里层循环次数：96 ，每次的损失: 0.1849
# 里层循环次数：97 ，每次的损失: 0.1536
# 里层循环次数：98 ，每次的损失: 0.1070
# 里层循环次数：99 ，每次的损失: 0.1311
# ------执行的次数是: 7 损失函数是: 0.1369------
# 里层循环次数：0 ，每次的损失: 0.0756
# 里层循环次数：1 ，每次的损失: 0.1270
# 里层循环次数：2 ，每次的损失: 0.1565
# 里层循环次数：3 ，每次的损失: 0.1190
# 里层循环次数：4 ，每次的损失: 0.1354
# 里层循环次数：5 ，每次的损失: 0.0911
# 里层循环次数：6 ，每次的损失: 0.0856
# 里层循环次数：7 ，每次的损失: 0.1330
# 里层循环次数：8 ，每次的损失: 0.1509
# 里层循环次数：9 ，每次的损失: 0.1395
# 里层循环次数：10 ，每次的损失: 0.1638
# 里层循环次数：11 ，每次的损失: 0.0946
# 里层循环次数：12 ，每次的损失: 0.1051
# 里层循环次数：13 ，每次的损失: 0.1944
# 里层循环次数：14 ，每次的损失: 0.0860
# 里层循环次数：15 ，每次的损失: 0.0985
# 里层循环次数：16 ，每次的损失: 0.1561
# 里层循环次数：17 ，每次的损失: 0.1368
# 里层循环次数：18 ，每次的损失: 0.0887
# 里层循环次数：19 ，每次的损失: 0.1226
# 里层循环次数：20 ，每次的损失: 0.1465
# 里层循环次数：21 ，每次的损失: 0.1621
# 里层循环次数：22 ，每次的损失: 0.1578
# 里层循环次数：23 ，每次的损失: 0.1480
# 里层循环次数：24 ，每次的损失: 0.0941
# 里层循环次数：25 ，每次的损失: 0.1048
# 里层循环次数：26 ，每次的损失: 0.2025
# 里层循环次数：27 ，每次的损失: 0.0758
# 里层循环次数：28 ，每次的损失: 0.1109
# 里层循环次数：29 ，每次的损失: 0.0911
# 里层循环次数：30 ，每次的损失: 0.1204
# 里层循环次数：31 ，每次的损失: 0.1024
# 里层循环次数：32 ，每次的损失: 0.1884
# 里层循环次数：33 ，每次的损失: 0.0935
# 里层循环次数：34 ，每次的损失: 0.1111
# 里层循环次数：35 ，每次的损失: 0.1221
# 里层循环次数：36 ，每次的损失: 0.1157
# 里层循环次数：37 ，每次的损失: 0.0917
# 里层循环次数：38 ，每次的损失: 0.1471
# 里层循环次数：39 ，每次的损失: 0.1619
# 里层循环次数：40 ，每次的损失: 0.0831
# 里层循环次数：41 ，每次的损失: 0.1230
# 里层循环次数：42 ，每次的损失: 0.1459
# 里层循环次数：43 ，每次的损失: 0.0876
# 里层循环次数：44 ，每次的损失: 0.1407
# 里层循环次数：45 ，每次的损失: 0.1167
# 里层循环次数：46 ，每次的损失: 0.1254
# 里层循环次数：47 ，每次的损失: 0.0751
# 里层循环次数：48 ，每次的损失: 0.1273
# 里层循环次数：49 ，每次的损失: 0.1070
# 里层循环次数：50 ，每次的损失: 0.1302
# 里层循环次数：51 ，每次的损失: 0.1203
# 里层循环次数：52 ，每次的损失: 0.1128
# 里层循环次数：53 ，每次的损失: 0.1699
# 里层循环次数：54 ，每次的损失: 0.1427
# 里层循环次数：55 ，每次的损失: 0.1548
# 里层循环次数：56 ，每次的损失: 0.0907
# 里层循环次数：57 ，每次的损失: 0.1036
# 里层循环次数：58 ，每次的损失: 0.1124
# 里层循环次数：59 ，每次的损失: 0.1509
# 里层循环次数：60 ，每次的损失: 0.0808
# 里层循环次数：61 ，每次的损失: 0.1151
# 里层循环次数：62 ，每次的损失: 0.1514
# 里层循环次数：63 ，每次的损失: 0.1200
# 里层循环次数：64 ，每次的损失: 0.0902
# 里层循环次数：65 ，每次的损失: 0.0816
# 里层循环次数：66 ，每次的损失: 0.0731
# 里层循环次数：67 ，每次的损失: 0.1186
# 里层循环次数：68 ，每次的损失: 0.1489
# 里层循环次数：69 ，每次的损失: 0.1610
# 里层循环次数：70 ，每次的损失: 0.1269
# 里层循环次数：71 ，每次的损失: 0.1100
# 里层循环次数：72 ，每次的损失: 0.1321
# 里层循环次数：73 ，每次的损失: 0.1027
# 里层循环次数：74 ，每次的损失: 0.1020
# 里层循环次数：75 ，每次的损失: 0.1101
# 里层循环次数：76 ，每次的损失: 0.1314
# 里层循环次数：77 ，每次的损失: 0.0783
# 里层循环次数：78 ，每次的损失: 0.0997
# 里层循环次数：79 ，每次的损失: 0.1134
# 里层循环次数：80 ，每次的损失: 0.1239
# 里层循环次数：81 ，每次的损失: 0.1480
# 里层循环次数：82 ，每次的损失: 0.1480
# 里层循环次数：83 ，每次的损失: 0.0871
# 里层循环次数：84 ，每次的损失: 0.0798
# 里层循环次数：85 ，每次的损失: 0.1230
# 里层循环次数：86 ，每次的损失: 0.1280
# 里层循环次数：87 ，每次的损失: 0.1102
# 里层循环次数：88 ，每次的损失: 0.0980
# 里层循环次数：89 ，每次的损失: 0.0985
# 里层循环次数：90 ，每次的损失: 0.0867
# 里层循环次数：91 ，每次的损失: 0.1471
# 里层循环次数：92 ，每次的损失: 0.1348
# 里层循环次数：93 ，每次的损失: 0.0911
# 里层循环次数：94 ，每次的损失: 0.0883
# 里层循环次数：95 ，每次的损失: 0.1191
# 里层循环次数：96 ，每次的损失: 0.1323
# 里层循环次数：97 ，每次的损失: 0.1318
# 里层循环次数：98 ，每次的损失: 0.1014
# 里层循环次数：99 ，每次的损失: 0.1617
# ------执行的次数是: 8 损失函数是: 0.1201------
# 里层循环次数：0 ，每次的损失: 0.1230
# 里层循环次数：1 ，每次的损失: 0.1021
# 里层循环次数：2 ，每次的损失: 0.1078
# 里层循环次数：3 ，每次的损失: 0.1288
# 里层循环次数：4 ，每次的损失: 0.1411
# 里层循环次数：5 ，每次的损失: 0.1034
# 里层循环次数：6 ，每次的损失: 0.0869
# 里层循环次数：7 ，每次的损失: 0.1038
# 里层循环次数：8 ，每次的损失: 0.1148
# 里层循环次数：9 ，每次的损失: 0.1014
# 里层循环次数：10 ，每次的损失: 0.1183
# 里层循环次数：11 ，每次的损失: 0.0740
# 里层循环次数：12 ，每次的损失: 0.1879
# 里层循环次数：13 ，每次的损失: 0.0781
# 里层循环次数：14 ，每次的损失: 0.0967
# 里层循环次数：15 ，每次的损失: 0.1121
# 里层循环次数：16 ，每次的损失: 0.0935
# 里层循环次数：17 ，每次的损失: 0.1259
# 里层循环次数：18 ，每次的损失: 0.0961
# 里层循环次数：19 ，每次的损失: 0.1060
# 里层循环次数：20 ，每次的损失: 0.0868
# 里层循环次数：21 ，每次的损失: 0.1683
# 里层循环次数：22 ，每次的损失: 0.1223
# 里层循环次数：23 ，每次的损失: 0.0954
# 里层循环次数：24 ，每次的损失: 0.1699
# 里层循环次数：25 ，每次的损失: 0.1393
# 里层循环次数：26 ，每次的损失: 0.1053
# 里层循环次数：27 ，每次的损失: 0.0942
# 里层循环次数：28 ，每次的损失: 0.1708
# 里层循环次数：29 ，每次的损失: 0.0746
# 里层循环次数：30 ，每次的损失: 0.1317
# 里层循环次数：31 ，每次的损失: 0.1142
# 里层循环次数：32 ，每次的损失: 0.1197
# 里层循环次数：33 ，每次的损失: 0.1463
# 里层循环次数：34 ，每次的损失: 0.1232
# 里层循环次数：35 ，每次的损失: 0.0952
# 里层循环次数：36 ，每次的损失: 0.1224
# 里层循环次数：37 ，每次的损失: 0.1176
# 里层循环次数：38 ，每次的损失: 0.1141
# 里层循环次数：39 ，每次的损失: 0.1368
# 里层循环次数：40 ，每次的损失: 0.1325
# 里层循环次数：41 ，每次的损失: 0.0919
# 里层循环次数：42 ，每次的损失: 0.0923
# 里层循环次数：43 ，每次的损失: 0.0816
# 里层循环次数：44 ，每次的损失: 0.1194
# 里层循环次数：45 ，每次的损失: 0.1267
# 里层循环次数：46 ，每次的损失: 0.1120
# 里层循环次数：47 ，每次的损失: 0.1308
# 里层循环次数：48 ，每次的损失: 0.1397
# 里层循环次数：49 ，每次的损失: 0.1746
# 里层循环次数：50 ，每次的损失: 0.0780
# 里层循环次数：51 ，每次的损失: 0.0853
# 里层循环次数：52 ，每次的损失: 0.1177
# 里层循环次数：53 ，每次的损失: 0.1202
# 里层循环次数：54 ，每次的损失: 0.1541
# 里层循环次数：55 ，每次的损失: 0.1101
# 里层循环次数：56 ，每次的损失: 0.1022
# 里层循环次数：57 ，每次的损失: 0.0626
# 里层循环次数：58 ，每次的损失: 0.0726
# 里层循环次数：59 ，每次的损失: 0.1123
# 里层循环次数：60 ，每次的损失: 0.1018
# 里层循环次数：61 ，每次的损失: 0.1858
# 里层循环次数：62 ，每次的损失: 0.1428
# 里层循环次数：63 ，每次的损失: 0.0978
# 里层循环次数：64 ，每次的损失: 0.1380
# 里层循环次数：65 ，每次的损失: 0.0903
# 里层循环次数：66 ，每次的损失: 0.1743
# 里层循环次数：67 ，每次的损失: 0.1428
# 里层循环次数：68 ，每次的损失: 0.0756
# 里层循环次数：69 ，每次的损失: 0.0539
# 里层循环次数：70 ，每次的损失: 0.1500
# 里层循环次数：71 ，每次的损失: 0.1809
# 里层循环次数：72 ，每次的损失: 0.1514
# 里层循环次数：73 ，每次的损失: 0.0807
# 里层循环次数：74 ，每次的损失: 0.1462
# 里层循环次数：75 ，每次的损失: 0.0867
# 里层循环次数：76 ，每次的损失: 0.0979
# 里层循环次数：77 ，每次的损失: 0.0904
# 里层循环次数：78 ，每次的损失: 0.0834
# 里层循环次数：79 ，每次的损失: 0.0760
# 里层循环次数：80 ，每次的损失: 0.1438
# 里层循环次数：81 ，每次的损失: 0.0979
# 里层循环次数：82 ，每次的损失: 0.1021
# 里层循环次数：83 ，每次的损失: 0.0920
# 里层循环次数：84 ，每次的损失: 0.0798
# 里层循环次数：85 ，每次的损失: 0.1404
# 里层循环次数：86 ，每次的损失: 0.1155
# 里层循环次数：87 ，每次的损失: 0.0996
# 里层循环次数：88 ，每次的损失: 0.1069
# 里层循环次数：89 ，每次的损失: 0.1113
# 里层循环次数：90 ，每次的损失: 0.0902
# 里层循环次数：91 ，每次的损失: 0.0886
# 里层循环次数：92 ，每次的损失: 0.0812
# 里层循环次数：93 ，每次的损失: 0.1095
# 里层循环次数：94 ，每次的损失: 0.0963
# 里层循环次数：95 ，每次的损失: 0.1201
# 里层循环次数：96 ，每次的损失: 0.1071
# 里层循环次数：97 ，每次的损失: 0.0855
# 里层循环次数：98 ，每次的损失: 0.1491
# 里层循环次数：99 ，每次的损失: 0.1150
# ------执行的次数是: 9 损失函数是: 0.1135------

# %%
# from numba import cuda

# cuda.select_device(0) # 选择GPU设备
# cuda.close(

# %%
with tf.compat.v1.Session() as sess:
    saver.restore(sess,"./cnn/model-9")
    x_test,y_test=mnist.test.next_batch(batch_size=2000)
    res=sess.run(prob,feed_dict={X:x_test,kp:0.999})
    y_test=y_test.argmax(axis=-1)
    res=res.argmax(axis=-1)
    print((y_test==res).mean())
    print(y_test.shape)
    print(res.shape)
# Out:
# INFO:tensorflow:Restoring parameters from ./cnn/model-9
# 0.1375
# (2000,)
# (2000,)
